# %% [markdown]
# <a href="https://colab.research.google.com/github/Chicaeme/Ejercicio-tarea-PANDAS/blob/main/tareitapandasxd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Ruta al archivo CSV descargado
ruta_archivo = "Plantas POO.csv"

# Cargar el archivo CSV en un DataFrame de Pandas
dataframe = pd.read_csv(ruta_archivo)

# Mostrar las primeras filas del DataFrame para verificar que se cargaron correctamente
print(dataframe.head())
# Out:
#    taxref10.CD_REF      binome.discoweed         family    taxo  \
# 0          79684.0  ABUTILON THEOPHRASTI      Malvaceae  binome
# 1          79734.0        ACER CAMPESTRE    Sapindaceae  binome
# 2          79783.0   ACER PSEUDOPLATANUS    Sapindaceae  binome
# 3          79908.0  ACHILLEA MILLEFOLIUM     Asteraceae  binome
# 4          80211.0     ADONIS AESTIVALIS  Ranunculaceae  binome
#
#   binome.discoweed.noinfra taxref10.CD_REF.infra  jauzein  za  biovigilance  \
# 0     ABUTILON THEOPHRASTI                 79684        1   0             1
# 1           ACER CAMPESTRE                 79734        0   0             0
# 2      ACER PSEUDOPLATANUS                 79783        0   0             1
# 3     ACHILLEA MILLEFOLIUM                 79908        1   1             1
# 4        ADONIS AESTIVALIS                 80211        1   0             1
#
#    fse  farmbio  cambecedes         lifeform                biogeo red.FR  \
# ...

# %%
dataframe.describe()
# Out:
#        taxref10.CD_REF      jauzein           za  biovigilance          fse  \
# count      1575.000000  1577.000000  1577.000000   1577.000000  1577.000000
# mean     136844.050159     0.889030     0.253012      0.210526     0.206088
# std      130777.529952     0.314195     0.434876      0.407812     0.404622
# min       79684.000000     0.000000     0.000000      0.000000     0.000000
# 25%       93864.500000     1.000000     0.000000      0.000000     0.000000
# 50%      106765.000000     1.000000     0.000000      0.000000     0.000000
# 75%      123540.500000     1.000000     1.000000      0.000000     0.000000
# max      789032.000000     1.000000     1.000000      1.000000     1.000000
#
#            farmbio   cambecedes       module            c            z
# count  1577.000000  1577.000000  1297.000000  1187.000000  1187.000000
# mean      0.085606     0.164236    12.488049     0.368623     2.930421
# std       0.279869     0.370607    26.293630     0.254429     5.508763
# ...

# %%
dataframe.head()
# Out:
#    taxref10.CD_REF      binome.discoweed         family    taxo  \
# 0          79684.0  ABUTILON THEOPHRASTI      Malvaceae  binome
# 1          79734.0        ACER CAMPESTRE    Sapindaceae  binome
# 2          79783.0   ACER PSEUDOPLATANUS    Sapindaceae  binome
# 3          79908.0  ACHILLEA MILLEFOLIUM     Asteraceae  binome
# 4          80211.0     ADONIS AESTIVALIS  Ranunculaceae  binome
#
#   binome.discoweed.noinfra taxref10.CD_REF.infra  jauzein  za  biovigilance  \
# 0     ABUTILON THEOPHRASTI                 79684        1   0             1
# 1           ACER CAMPESTRE                 79734        0   0             0
# 2      ACER PSEUDOPLATANUS                 79783        0   0             1
# 3     ACHILLEA MILLEFOLIUM                 79908        1   1             1
# 4        ADONIS AESTIVALIS                 80211        1   0             1
#
#    fse  farmbio  cambecedes         lifeform                biogeo red.FR  \
# ...

# %%
filas = dataframe.iloc[0,1]
filas
# Out:
# 'ABUTILON THEOPHRASTI'

# %%
miserie=dataframe['jauzein']
miserie.head()
sumacolumna = miserie.sum()
sumacolumna
# Out:
# 1402
